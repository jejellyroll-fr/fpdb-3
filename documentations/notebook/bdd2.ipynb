# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlite3
import pandas as pd
import numpy as np
from IPython.display import display, HTML
path = "C:/Users/jd/AppData/Roaming/fpdb/database/fpdb.db3"
#path = "/Users/xxx/.fpdb/database/fpdb.db3"
con = sqlite3.connect(path)

cur = con.cursor()

cur.execute("""SELECT name FROM sqlite_master
            WHERE type='table'
            ORDER BY name;""")

result = cur.fetchall()

print(result)
# Out:
# [('Actions',), ('Autorates',), ('Backings',), ('Boards',), ('CardsCache',), ('Files',), ('Gametypes',), ('Hands',), ('HandsActions',), ('HandsPlayers',), ('HandsPots',), ('HandsStove',), ('HudCache',), ('Months',), ('Players',), ('PositionsCache',), ('Rank',), ('RawHands',), ('RawTourneys',), ('Sessions',), ('SessionsCache',), ('Settings',), ('Sites',), ('StartCards',), ('TourneyTypes',), ('Tourneys',), ('TourneysCache',), ('TourneysPlayers',), ('Weeks',), ('sqlite_stat1',)]

# %%
cur.execute("""SELECT * FROM Tourneys limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()


df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>tourneyTypeId</th>
#       <th>sessionId</th>
#       <th>siteTourneyNo</th>
#       <th>entries</th>
#       <th>prizepool</th>
#       <th>startTime</th>
#       <th>endTime</th>
#       <th>tourneyName</th>
#       <th>totalRebuyCount</th>
#       <th>totalAddOnCount</th>
#       <th>added</th>
#       <th>addedCurrency</th>
#       <th>comment</th>
#       <th>commentTs</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM Actions limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>ante</td>
#       <td>A</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>small blind</td>
#       <td>SB</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>secondsb</td>
#       <td>SSB</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>big blind</td>
#       <td>BB</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>both</td>
#       <td>SBBB</td>
#     </tr>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM Autorates limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>playerId</th>
#       <th>gametypeId</th>
#       <th>description</th>
#       <th>shortDesc</th>
#       <th>ratingTime</th>
#       <th>handCount</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM Boards limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>handId</th>
#       <th>boardId</th>
#       <th>boardcard1</th>
#       <th>boardcard2</th>
#       <th>boardcard3</th>
#       <th>boardcard4</th>
#       <th>boardcard5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>3</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>63</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>7</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
# ...

# %%
cur.execute("""SELECT * FROM CardsCache limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>weekId</th>
#       <th>monthId</th>
#       <th>gametypeId</th>
#       <th>tourneyTypeId</th>
#       <th>playerId</th>
#       <th>startCards</th>
#       <th>n</th>
#       <th>street0VPIChance</th>
#       <th>street0VPI</th>
#       <th>street0AggrChance</th>
#       <th>street0Aggr</th>
#       <th>street0CalledRaiseChance</th>
#       <th>street0CalledRaiseDone</th>
#       <th>street0_2BChance</th>
#       <th>street0_2BDone</th>
#       <th>street0_3BChance</th>
#       <th>street0_3BDone</th>
#       <th>street0_4BChance</th>
#       <th>street0_4BDone</th>
#       <th>street0_C4BChance</th>
#       <th>street0_C4BDone</th>
#       <th>street0_FoldTo2BChance</th>
#       <th>street0_FoldTo2BDone</th>
#       <th>street0_FoldTo3BChance</th>
#       <th>street0_FoldTo3BDone</th>
#       <th>street0_FoldTo4BChance</th>
# ...

# %%
cur.execute("""SELECT * FROM Files where errs<>0 limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>file</th>
#       <th>site</th>
#       <th>type</th>
#       <th>startTime</th>
#       <th>lastUpdate</th>
#       <th>endTime</th>
#       <th>hands</th>
#       <th>storedHands</th>
#       <th>dups</th>
#       <th>partial</th>
#       <th>skipped</th>
#       <th>errs</th>
#       <th>ttime100</th>
#       <th>finished</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1323</td>
#       <td>GG20230207-1249 - PLOYellow8 - 0.02 - 0.05 - 6max</td>
#       <td>GGPoker</td>
#       <td>bulk</td>
#       <td>2023-03-07 16:06:11.149466</td>
#       <td>2023-03-07 16:09:41.576581</td>
#       <td>2023-03-07 16:09:41.576581</td>
#       <td>105</td>
#       <td>104</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>27.076864</td>
#       <td>1</td>
#     </tr>
#     <tr>
# ...

# %%
cur.execute("""SELECT * FROM Gametypes limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>siteId</th>
#       <th>currency</th>
#       <th>type</th>
#       <th>base</th>
#       <th>category</th>
#       <th>limitType</th>
#       <th>hiLo</th>
#       <th>mix</th>
#       <th>smallBlind</th>
#       <th>bigBlind</th>
#       <th>smallBet</th>
#       <th>bigBet</th>
#       <th>maxSeats</th>
#       <th>ante</th>
#       <th>buyinType</th>
#       <th>fast</th>
#       <th>newToGame</th>
#       <th>homeGame</th>
#       <th>split</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>27</td>
#       <td>USD</td>
#       <td>ring</td>
#       <td>hold</td>
#       <td>omahahi</td>
#       <td>pl</td>
#       <td>h</td>
#       <td>none</td>
#       <td>2</td>
#       <td>5</td>
#       <td>5</td>
#       <td>10</td>
#       <td>6</td>
#       <td>0</td>
#       <td>regular</td>
# ...

# %%
cur.execute("""SELECT * FROM Hands WHERE siteHandNo == 342930825""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>tableName</th>
#       <th>siteHandNo</th>
#       <th>tourneyId</th>
#       <th>gametypeId</th>
#       <th>sessionId</th>
#       <th>fileId</th>
#       <th>startTime</th>
#       <th>importTime</th>
#       <th>seats</th>
#       <th>heroSeat</th>
#       <th>maxPosition</th>
#       <th>boardcard1</th>
#       <th>boardcard2</th>
#       <th>boardcard3</th>
#       <th>boardcard4</th>
#       <th>boardcard5</th>
#       <th>texture</th>
#       <th>runItTwice</th>
#       <th>playersVpi</th>
#       <th>playersAtStreet1</th>
#       <th>playersAtStreet2</th>
#       <th>playersAtStreet3</th>
#       <th>playersAtStreet4</th>
#       <th>playersAtShowdown</th>
#       <th>street0Raises</th>
#       <th>street1Raises</th>
#       <th>street2Raises</th>
#       <th>street3Raises</th>
#       <th>street4Raises</th>
#       <th>street0Pot</th>
# ...

# %%
cur.execute("""SELECT * FROM HandsActions limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>handId</th>
#       <th>playerId</th>
#       <th>street</th>
#       <th>actionNo</th>
#       <th>streetActionNo</th>
#       <th>actionId</th>
#       <th>amount</th>
#       <th>raiseTo</th>
#       <th>amountCalled</th>
#       <th>numDiscarded</th>
#       <th>cardsDiscarded</th>
#       <th>allIn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>4</td>
#       <td>-1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1</td>
#       <td>5</td>
#       <td>-1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>4</td>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
# ...

# %%
cur.execute("""SELECT * FROM HandsPlayers limit 25""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>handId</th>
#       <th>playerId</th>
#       <th>startCash</th>
#       <th>effStack</th>
#       <th>startBounty</th>
#       <th>endBounty</th>
#       <th>position</th>
#       <th>seatNo</th>
#       <th>sitout</th>
#       <th>card1</th>
#       <th>card2</th>
#       <th>card3</th>
#       <th>card4</th>
#       <th>card5</th>
#       <th>card6</th>
#       <th>card7</th>
#       <th>card8</th>
#       <th>card9</th>
#       <th>card10</th>
#       <th>card11</th>
#       <th>card12</th>
#       <th>card13</th>
#       <th>card14</th>
#       <th>card15</th>
#       <th>card16</th>
#       <th>card17</th>
#       <th>card18</th>
#       <th>card19</th>
#       <th>card20</th>
#       <th>startCards</th>
#       <th>common</th>
#       <th>committed</th>
#       <th>winnings</th>
#       <th>rake</th>
#       <th>rakeDealt</th>
# ...

# %%
cur.execute("""SELECT * FROM HandsPots limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>handId</th>
#       <th>potId</th>
#       <th>boardId</th>
#       <th>hiLo</th>
#       <th>playerId</th>
#       <th>pot</th>
#       <th>collected</th>
#       <th>rake</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM HandsStove limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>handId</th>
#       <th>playerId</th>
#       <th>streetId</th>
#       <th>boardId</th>
#       <th>hiLo</th>
#       <th>rankId</th>
#       <th>value</th>
#       <th>cards</th>
#       <th>ev</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM HudCache limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>gametypeId</th>
#       <th>playerId</th>
#       <th>seats</th>
#       <th>position</th>
#       <th>tourneyTypeId</th>
#       <th>styleKey</th>
#       <th>n</th>
#       <th>street0VPIChance</th>
#       <th>street0VPI</th>
#       <th>street0AggrChance</th>
#       <th>street0Aggr</th>
#       <th>street0CalledRaiseChance</th>
#       <th>street0CalledRaiseDone</th>
#       <th>street0_2BChance</th>
#       <th>street0_2BDone</th>
#       <th>street0_3BChance</th>
#       <th>street0_3BDone</th>
#       <th>street0_4BChance</th>
#       <th>street0_4BDone</th>
#       <th>street0_C4BChance</th>
#       <th>street0_C4BDone</th>
#       <th>street0_FoldTo2BChance</th>
#       <th>street0_FoldTo2BDone</th>
#       <th>street0_FoldTo3BChance</th>
#       <th>street0_FoldTo3BDone</th>
#       <th>street0_FoldTo4BChance</th>
# ...

# %%
cur.execute("""SELECT * FROM Months limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>monthStart</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM Players limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>siteId</th>
#       <th>hero</th>
#       <th>chars</th>
#       <th>comment</th>
#       <th>commentTs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>184adf90</td>
#       <td>27</td>
#       <td>0</td>
#       <td>123</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>3b520b34</td>
#       <td>27</td>
#       <td>0</td>
#       <td>123</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1f1f7b1f</td>
#       <td>27</td>
#       <td>0</td>
#       <td>123</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>9f74da09</td>
#       <td>27</td>
#       <td>0</td>
# ...

# %%
cur.execute("""SELECT * FROM PositionsCache limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>weekId</th>
#       <th>monthId</th>
#       <th>gametypeId</th>
#       <th>tourneyTypeId</th>
#       <th>playerId</th>
#       <th>seats</th>
#       <th>maxPosition</th>
#       <th>position</th>
#       <th>n</th>
#       <th>street0VPIChance</th>
#       <th>street0VPI</th>
#       <th>street0AggrChance</th>
#       <th>street0Aggr</th>
#       <th>street0CalledRaiseChance</th>
#       <th>street0CalledRaiseDone</th>
#       <th>street0_2BChance</th>
#       <th>street0_2BDone</th>
#       <th>street0_3BChance</th>
#       <th>street0_3BDone</th>
#       <th>street0_4BChance</th>
#       <th>street0_4BDone</th>
#       <th>street0_C4BChance</th>
#       <th>street0_C4BDone</th>
#       <th>street0_FoldTo2BChance</th>
#       <th>street0_FoldTo2BDone</th>
#       <th>street0_FoldTo3BChance</th>
#       <th>street0_FoldTo3BDone</th>
# ...

# %%
cur.execute("""SELECT * FROM Rank limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Nothing</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>NoPair</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>OnePair</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>TwoPair</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Trips</td>
#     </tr>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM RawHands limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>handId</th>
#       <th>rawHand</th>
#       <th>complain</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM RawTourneys limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>tourneyId</th>
#       <th>rawTourney</th>
#       <th>complain</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM Sessions limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>weekId</th>
#       <th>monthId</th>
#       <th>sessionStart</th>
#       <th>sessionEnd</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM SessionsCache limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>sessionId</th>
#       <th>startTime</th>
#       <th>endTime</th>
#       <th>gametypeId</th>
#       <th>playerId</th>
#       <th>n</th>
#       <th>street0VPIChance</th>
#       <th>street0VPI</th>
#       <th>street0AggrChance</th>
#       <th>street0Aggr</th>
#       <th>street0CalledRaiseChance</th>
#       <th>street0CalledRaiseDone</th>
#       <th>street0_2BChance</th>
#       <th>street0_2BDone</th>
#       <th>street0_3BChance</th>
#       <th>street0_3BDone</th>
#       <th>street0_4BChance</th>
#       <th>street0_4BDone</th>
#       <th>street0_C4BChance</th>
#       <th>street0_C4BDone</th>
#       <th>street0_FoldTo2BChance</th>
#       <th>street0_FoldTo2BDone</th>
#       <th>street0_FoldTo3BChance</th>
#       <th>street0_FoldTo3BDone</th>
#       <th>street0_FoldTo4BChance</th>
#       <th>street0_FoldTo4BDone</th>
# ...

# %%
cur.execute("""SELECT * FROM Settings limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>216</td>
#     </tr>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM Sites""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Full Tilt Poker</td>
#       <td>FT</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>PokerStars</td>
#       <td>PS</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Everleaf</td>
#       <td>EV</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Boss</td>
#       <td>BM</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>OnGame</td>
#       <td>OG</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>UltimateBet</td>
#       <td>UB</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>Betfair</td>
#       <td>BF</td>
#     </tr>
#     <tr>
#       <th>7</th>
# ...

# %%
cur.execute("""SELECT * FROM StartCards limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>category</th>
#       <th>name</th>
#       <th>rank</th>
#       <th>combinations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>holdem</td>
#       <td>22</td>
#       <td>54</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>holdem</td>
#       <td>32o</td>
#       <td>160</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>holdem</td>
#       <td>42o</td>
#       <td>157</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>holdem</td>
#       <td>52o</td>
#       <td>154</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>holdem</td>
#       <td>62o</td>
#       <td>164</td>
#       <td>24</td>
#     </tr>
# ...

# %%
cur.execute("""SELECT * FROM TourneyTypes""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>siteId</th>
#       <th>currency</th>
#       <th>buyin</th>
#       <th>fee</th>
#       <th>category</th>
#       <th>limitType</th>
#       <th>buyInChips</th>
#       <th>stack</th>
#       <th>maxSeats</th>
#       <th>rebuy</th>
#       <th>rebuyCost</th>
#       <th>rebuyFee</th>
#       <th>rebuyChips</th>
#       <th>addOn</th>
#       <th>addOnCost</th>
#       <th>addOnFee</th>
#       <th>addOnChips</th>
#       <th>knockout</th>
#       <th>koBounty</th>
#       <th>progressive</th>
#       <th>step</th>
#       <th>stepNo</th>
#       <th>chance</th>
#       <th>chanceCount</th>
#       <th>speed</th>
#       <th>shootout</th>
#       <th>matrix</th>
#       <th>multiEntry</th>
#       <th>reEntry</th>
#       <th>fast</th>
#       <th>newToGame</th>
#       <th>homeGame</th>
#       <th>split</th>
#       <th>sng</th>
# ...

# %%
cur.execute("""SELECT * FROM Tourneys limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>tourneyTypeId</th>
#       <th>sessionId</th>
#       <th>siteTourneyNo</th>
#       <th>entries</th>
#       <th>prizepool</th>
#       <th>startTime</th>
#       <th>endTime</th>
#       <th>tourneyName</th>
#       <th>totalRebuyCount</th>
#       <th>totalAddOnCount</th>
#       <th>added</th>
#       <th>addedCurrency</th>
#       <th>comment</th>
#       <th>commentTs</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM TourneysCache limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>sessionId</th>
#       <th>startTime</th>
#       <th>endTime</th>
#       <th>tourneyId</th>
#       <th>playerId</th>
#       <th>n</th>
#       <th>street0VPIChance</th>
#       <th>street0VPI</th>
#       <th>street0AggrChance</th>
#       <th>street0Aggr</th>
#       <th>street0CalledRaiseChance</th>
#       <th>street0CalledRaiseDone</th>
#       <th>street0_2BChance</th>
#       <th>street0_2BDone</th>
#       <th>street0_3BChance</th>
#       <th>street0_3BDone</th>
#       <th>street0_4BChance</th>
#       <th>street0_4BDone</th>
#       <th>street0_C4BChance</th>
#       <th>street0_C4BDone</th>
#       <th>street0_FoldTo2BChance</th>
#       <th>street0_FoldTo2BDone</th>
#       <th>street0_FoldTo3BChance</th>
#       <th>street0_FoldTo3BDone</th>
#       <th>street0_FoldTo4BChance</th>
#       <th>street0_FoldTo4BDone</th>
# ...

# %%
cur.execute("""SELECT * FROM TourneysPlayers limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>tourneyId</th>
#       <th>playerId</th>
#       <th>entryId</th>
#       <th>rank</th>
#       <th>winnings</th>
#       <th>winningsCurrency</th>
#       <th>rebuyCount</th>
#       <th>addOnCount</th>
#       <th>koCount</th>
#       <th>comment</th>
#       <th>commentTs</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT * FROM Weeks limit 5""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>weekStart</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT tp.tourneyId, (coalesce(tp.winnings,0) - coalesce(tt.buyIn,0) - coalesce(tt.fee,0)) as profit, tp.koCount, tp.rebuyCount, tp.addOnCount, tt.buyIn, tt.fee, t.siteTourneyNo
            FROM TourneysPlayers tp
            INNER JOIN Players pl      ON  (pl.id = tp.playerId)
            INNER JOIN Tourneys t         ON  (t.id  = tp.tourneyId)
            INNER JOIN TourneyTypes tt    ON  (tt.id = t.tourneyTypeId)
            WHERE pl.id in (3)
            AND   pl.siteId in (2, 9, 15, 14, 27, 30)
            AND tt.limitType in ("nl")
             AND tt.category in ("holdem")
            AND   (t.startTime > '1970-01-01 04:00:00' AND t.startTime < '2100-01-02 03:59:59')
                 AND tt.currency in ('EUR', 'USD', '')
            GROUP BY t.startTime, tp.tourneyId, tp.winningsCurrency,
                     tp.winnings, tp.koCount,
                     tp.rebuyCount, tp.addOnCount,
                     tt.buyIn, tt.fee, t.siteTourneyNo
            ORDER BY t.startTime""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tourneyId</th>
#       <th>profit</th>
#       <th>koCount</th>
#       <th>rebuyCount</th>
#       <th>addOnCount</th>
#       <th>buyin</th>
#       <th>fee</th>
#       <th>siteTourneyNo</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT DISTINCT category FROM TourneyTypes""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT DISTINCT limitType FROM TourneyTypes""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>limitType</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cur.execute("""SELECT name FROM sqlite_master
                                            WHERE type='index'
                                            ORDER BY name;""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()


df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Backings_playerId_idx</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Backings_tourneysPlayersId_idx</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Boards_handId_idx</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>CardsCache_Compound_idx</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Gametypes_siteId_idx</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>HandsActions_actionId_idx</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>HandsActions_handId_idx</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>HandsActions_playerId_idx</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>HandsPlayers_handId_idx</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>HandsPlayers_playerId_idx</td>
#     </tr>
# ...

# %%
cur.execute("""PRAGMA table_info(Actions)""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()

print("Actions:")
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# Actions:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cid</th>
#       <th>name</th>
#       <th>type</th>
#       <th>notnull</th>
#       <th>dflt_value</th>
#       <th>pk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>id</td>
#       <td>INTEGER</td>
#       <td>0</td>
#       <td>None</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>name</td>
#       <td>TEXT</td>
#       <td>1</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>code</td>
#       <td>TEXT</td>
#       <td>1</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %%
cur.execute("""PRAGMA table_info(Autorates)""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()

print("Autorates:")
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# Autorates:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cid</th>
#       <th>name</th>
#       <th>type</th>
#       <th>notnull</th>
#       <th>dflt_value</th>
#       <th>pk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>id</td>
#       <td>INTEGER</td>
#       <td>0</td>
#       <td>None</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>playerId</td>
#       <td>INT</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>gametypeId</td>
#       <td>INT</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>description</td>
#       <td>TEXT</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
# ...

# %%
cur.execute("""PRAGMA table_info(Backings)""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()

print("Backings:")
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))
# Out:
# Backings:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cid</th>
#       <th>name</th>
#       <th>type</th>
#       <th>notnull</th>
#       <th>dflt_value</th>
#       <th>pk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>id</td>
#       <td>INTEGER</td>
#       <td>0</td>
#       <td>None</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>tourneysPlayersId</td>
#       <td>INT</td>
#       <td>1</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>playerId</td>
#       <td>INT</td>
#       <td>1</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>buyInPercentage</td>
#       <td>REAL UNSIGNED</td>
#       <td>1</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
# ...

# %%
cur.execute("""PRAGMA table_info(Boards)""")
names = list(map(lambda x: x[0], cur.description))
result = cur.fetchall()

print("Boards:")
df = pd.DataFrame(result, columns=names)

display(HTML(df.to_html()))

# %%
import re

search_string = r"Winamax\s+([^\(]+)\(681029196\)\(#0\)"
w_title = "Winamax Kill The Fish(681029196)(#0)"

if re.search(search_string, w_title, re.I):
    print("Found")
else:
    print("Not Found")
# Out:
# Found
